# %% [markdown]
# **Цель работы** – оценить влияние учёта корреляции при расчёте энергии диссоциации молекул.
#
# #### Задачи
# 1. Методами HF, MP2 и CCSD(T) в выбранном базисе рассчитать энергию диссоциации выбранной молекулы. OPT NormalPrint PrintBasis PrintMOs
# 2. Проанализировать, сравнить с экспериментальными данными, сделать выводы.

# %%
import orca_parser
import matplotlib.pyplot as plt
from orca_parser import *
import ase, sys
import pandas as pd
print("1,2,3-thiodiazole HF 6-31(d,p) associated")
Optimization = ORCAParse("/Users/seanpaisti/Desktop/orca_tests/orca_lib/lab2/HF631dp/QCh_labHF631Gdp.out")
print("ORCA exited normally:", Optimization.valid)
print("Job took:", Optimization.seconds(), "seconds")

Optimization.parse_coords()
print("Atoms:", Optimization.atoms)
print("Final coordinates:")
pd.set_option('display.float_format', '{:.4e}'.format)
df = pd.DataFrame(Optimization.coords[-1])
df.columns = ['x', 'y', 'z']
df.index = ['H', 'N', 'C', 'S', 'C', 'N', 'H']
print(df)
Optimization.parse_energies()
print("Energy at convergence:")
print(Optimization.energies[-1], "Ha")
print(float(Optimization.energies[-1]) / 2.294e+17, "J")
Optimization.parse_free_energy()
print("Total SCF energy: -15870.88355 eV\n")

print("1,2,3-thiodiazole CCSD(T) 6-31(d,p) associated")
Optimization = ORCAParse("/Users/seanpaisti/Desktop/orca_tests/orca_lib/lab4/associated_mol/CCSDT/QCh_labCCSDT_631Gdp.out")
print("ORCA exited normally:", Optimization.valid)
print("Job took:", Optimization.seconds(), "seconds")

Optimization.parse_coords()
print("Atoms:", Optimization.atoms)
print("Final coordinates:")
pd.set_option('display.float_format', '{:.4e}'.format)
df = pd.DataFrame(Optimization.coords[-1])
df.columns = ['x', 'y', 'z']
df.index = ['H', 'N', 'C', 'S', 'C', 'N', 'H']
print(df)
Optimization.parse_energies()
print("Energy at convergence:")
print(Optimization.energies[-1], "Ha")
print(float(Optimization.energies[-1]) / 2.294e+17, "J")
Optimization.parse_free_energy()
print("Total SCF energy: -15870.88355 eV\n")

print("1,2,3-thiodiazole MP2 6-31(d,p) associated")
Optimization = ORCAParse("/Users/seanpaisti/Desktop/orca_tests/orca_lib/lab4/associated_mol/MP2/QCh_labMP2_631Gdp.out")
print("ORCA exited normally:", Optimization.valid)
print("Job took:", Optimization.seconds(), "seconds")

Optimization.parse_coords()
print("Atoms:", Optimization.atoms)
print("Final coordinates:")
pd.set_option('display.float_format', '{:.4e}'.format)
df = pd.DataFrame(Optimization.coords[-1])
df.columns = ['x', 'y', 'z']
df.index = ['H', 'N', 'C', 'S', 'C', 'N', 'H']
print(df)
Optimization.parse_energies()
print("Energy at convergence:")
print(Optimization.energies[-1], "Ha")
print(float(Optimization.energies[-1]) / 2.294e+17, "J")
Optimization.parse_free_energy()
print("Total SCF energy: -15870.88355 eV\n")
# Out:
# 1,2,3-thiodiazole HF 6-31(d,p) associated
# ORCA exited normally: True
# Job took: 6.871 seconds
# Atoms: ['H', 'N', 'C', 'S', 'C', 'N', 'H']
# Final coordinates:
#             x          y           z
# H -6.0425e+00 2.4437e+00 -3.6239e-01
# N -4.8054e+00 2.0627e+00  2.8676e+00
# C -5.6567e+00 2.1694e+00  5.9729e-01
# S -5.3240e+00 3.2809e+00  1.8385e+00
# C -5.3492e+00 9.4286e-01  1.0532e+00
# N -4.8722e+00 9.3657e-01  2.3416e+00
# H -5.4373e+00 1.3471e-02  5.2990e-01
# Energy at convergence:
# -583.24427364052 Ha
# -2.5424772172646902e-15 J
# Total SCF energy: -15870.88355 eV
#
# 1,2,3-thiodiazole CCSD(T) 6-31(d,p) associated
# ORCA exited normally: True
# Job took: 2841.09 seconds
# Atoms: ['H', 'N', 'C', 'S', 'C', 'N', 'H']
# Final coordinates:
#             x           y           z
# H -6.0486e+00  2.4504e+00 -3.7663e-01
# N -4.7908e+00  2.0669e+00  2.9085e+00
# C -5.6596e+00  2.1831e+00  5.9362e-01
# S -5.3348e+00  3.3199e+00  1.8211e+00
# C -5.3466e+00  9.2614e-01  1.0549e+00
# N -4.8659e+00  9.0714e-01  2.3497e+00
# H -5.4410e+00 -3.9860e-03  5.1448e-01
# Energy at convergence:
# -584.016427631698 Ha
# -2.545843189327367e-15 J
# Total SCF energy: -15870.88355 eV
#
# 1,2,3-thiodiazole MP2 6-31(d,p) associated
# ORCA exited normally: True
# Job took: 65.891 seconds
# Atoms: ['H', 'N', 'C', 'S', 'C', 'N', 'H']
# Final coordinates:
#             x           y           z
# H -6.0479e+00  2.4567e+00 -3.7306e-01
# N -4.7950e+00  2.0854e+00  2.9026e+00
# C -5.6594e+00  2.1870e+00  5.9530e-01
# S -5.3328e+00  3.2979e+00  1.8197e+00
# C -5.3428e+00  9.2421e-01  1.0646e+00
# N -4.8691e+00  8.9951e-01  2.3386e+00
# H -5.4401e+00 -1.1700e-03  5.1779e-01
# Energy at convergence:
# -583.963541666146 Ha
# -2.5456126489369925e-15 J
# Total SCF energy: -15870.88355 eV

# %%
print("1,2,3-thiodiazole HF 6-31(d,p) 4 - dissociated")
Optimization = ORCAParse("/Users/seanpaisti/Desktop/orca_tests/orca_lib/lab4/dissociated_mol/4dissassociated/HF/thiadiazoleHF_4dissassociated.out")
print("ORCA exited normally:", Optimization.valid)
print("Job took:", Optimization.seconds(), "seconds")

Optimization.parse_coords()
print("Atoms:", Optimization.atoms)
print("Final coordinates:")
pd.set_option('display.float_format', '{:.4e}'.format)
df = pd.DataFrame(Optimization.coords[-1])
df.columns = ['x', 'y', 'z']
df.index = ['N', 'C', 'S', 'C', 'N', 'H']
print(df)
Optimization.parse_energies()
print("Energy at convergence:")
print(Optimization.energies[-1], "Ha")
print(float(Optimization.energies[-1]) / 2.294e+17, "J")
Optimization.parse_free_energy()
print("Total SCF energy:  eV\n")

print("1,2,3-thiodiazole CCSD(T) 6-31(d,p) 4 - dissociated") #NUMGRAD enabled
Optimization = ORCAParse("/Users/seanpaisti/Desktop/orca_tests/orca_lib/lab4/dissociated_mol/4dissassociated/CCSDT/thiadiazoleCCSDT_4dissassociated.out")
print("ORCA exited normally:", Optimization.valid)
print("Job took:", Optimization.seconds(), "seconds")

Optimization.parse_coords()
print("Atoms:", Optimization.atoms)
print("Final coordinates:")
pd.set_option('display.float_format', '{:.4e}'.format)
df = pd.DataFrame(Optimization.coords[-1])
df.columns = ['x', 'y', 'z']
df.index = ['N', 'C', 'S', 'C', 'N', 'H']
print(df)
Optimization.parse_energies()
print("Energy at convergence:")
print(Optimization.energies[-1], "Ha")
print(float(Optimization.energies[-1]) / 2.294e+17, "J")
Optimization.parse_free_energy()
print("Total SCF energy:  eV\n")

print("1,2,3-thiodiazole MP2 6-31(d,p) 4 - dissociated")
Optimization = ORCAParse("/Users/seanpaisti/Desktop/orca_tests/orca_lib/lab4/dissociated_mol/4dissassociated/MP2/thiadiazoleMP2_4dissassociated.out")
print("ORCA exited normally:", Optimization.valid)
print("Job took:", Optimization.seconds(), "seconds")

Optimization.parse_coords()
print("Atoms:", Optimization.atoms)
print("Final coordinates:")
pd.set_option('display.float_format', '{:.4e}'.format)
df = pd.DataFrame(Optimization.coords[-1])
df.columns = ['x', 'y', 'z']
df.index = ['N', 'C', 'S', 'C', 'N', 'H']
print(df)
Optimization.parse_energies()
print("Energy at convergence:")
print(Optimization.energies[-1], "Ha")
print(float(Optimization.energies[-1]) / 2.294e+17, "J")
Optimization.parse_free_energy()
print("Total SCF energy:  eV")
# Out:
# 1,2,3-thiodiazole HF 6-31(d,p) 4 - dissociated
# ORCA exited normally: True
# Job took: 28.911 seconds
# Atoms: ['N', 'C', 'S', 'C', 'N', 'H']
# Final coordinates:
#             x          y           z
# N -4.8014e+00 2.0671e+00  2.8803e+00
# C -5.6651e+00 2.1656e+00  5.7353e-01
# S -5.3263e+00 3.2911e+00  1.8347e+00
# C -5.3375e+00 9.4537e-01  1.0848e+00
# N -4.8686e+00 9.0530e-01  2.3416e+00
# H -6.0502e+00 2.4217e+00 -3.8984e-01
# Energy at convergence:
# -582.592314295167 Ha
# -2.539635197450597e-15 J
# Total SCF energy:  eV
#
# 1,2,3-thiodiazole CCSD(T) 6-31(d,p) 4 - dissociated
# ORCA exited normally: True
# Job took: 11380.514 seconds
# Atoms: ['N', 'C', 'S', 'C', 'N', 'H']
# Final coordinates:
#             x          y           z
# N -4.7913e+00 2.0607e+00  2.9033e+00
# C -5.6659e+00 2.1690e+00  5.7501e-01
# S -5.3358e+00 3.3023e+00  1.8141e+00
# C -5.3395e+00 9.4502e-01  1.0806e+00
# N -4.8643e+00 8.9142e-01  2.3489e+00
# H -6.0524e+00 2.4277e+00 -3.9685e-01
# Energy at convergence:
# -583.323670343268 Ha
# -2.5428233232051785e-15 J
# Total SCF energy:  eV
#
# 1,2,3-thiodiazole MP2 6-31(d,p) 4 - dissociated
# ORCA exited normally: True
# Job took: 104.166 seconds
# Atoms: ['N', 'C', 'S', 'C', 'N', 'H']
# Final coordinates:
#             x          y           z
# N -4.8073e+00 2.0581e+00  2.8612e+00
# C -5.6562e+00 2.1563e+00  5.9452e-01
# S -5.3283e+00 3.2453e+00  1.8156e+00
# C -5.3439e+00 9.6983e-01  1.0755e+00
# N -4.8693e+00 9.3880e-01  2.3501e+00
# H -6.0442e+00 2.4279e+00 -3.7174e-01
# Energy at convergence:
# -583.237121210251 Ha
# -2.5424460384056278e-15 J
# Total SCF energy:  eV

# %%
print("1,2,3-thiodiazole HF 6-31(d,p) 5 - dissociated")
Optimization = ORCAParse("/Users/seanpaisti/Desktop/orca_tests/orca_lib/lab4/dissociated_mol/5dissassociated/HF/thiadiazoleHF_5dissassociated.out")
print("ORCA exited normally:", Optimization.valid)
print("Job took:", Optimization.seconds(), "seconds")

Optimization.parse_coords()
print("Atoms:", Optimization.atoms)
print("Final coordinates:")
pd.set_option('display.float_format', '{:.4e}'.format)
df = pd.DataFrame(Optimization.coords[-1])
df.columns = ['x', 'y', 'z']
df.index = ['N', 'C', 'S', 'C', 'N', 'H']
print(df)
Optimization.parse_energies()
print("Energy at convergence:")
print(Optimization.energies[-1], "Ha")
print(float(Optimization.energies[-1]) / 2.294e+17, "J")
Optimization.parse_free_energy()
print("Total SCF energy:  eV\n")

print("1,2,3-thiodiazole CCSD(T) 6-31(d,p) 5 - dissociated")
Optimization = ORCAParse("/Users/seanpaisti/Desktop/orca_tests/orca_lib/lab4/dissociated_mol/4dissassociated/CCSDT/thiadiazoleCCSDT_4dissassociated.out")
print("ORCA exited normally:", Optimization.valid)
print("Job took:", Optimization.seconds(), "seconds")

Optimization.parse_coords()
print("Atoms:", Optimization.atoms)
print("Final coordinates:")
pd.set_option('display.float_format', '{:.4e}'.format)
df = pd.DataFrame(Optimization.coords[-1])
df.columns = ['x', 'y', 'z']
df.index = ['N', 'C', 'S', 'C', 'N', 'H']
print(df)
Optimization.parse_energies()
print("Energy at convergence:")
print(Optimization.energies[-1], "Ha")
print(float(Optimization.energies[-1]) / 2.294e+17, "J")
Optimization.parse_free_energy()
print("Total SCF energy:  eV\n")

print("1,2,3-thiodiazole MP2 6-31(d,p) 5 - dissociated")
Optimization = ORCAParse("/Users/seanpaisti/Desktop/orca_tests/orca_lib/lab4/dissociated_mol/5dissassociated/MP2/thiadiazoleMP2_5dissassociated.out")
print("ORCA exited normally:", Optimization.valid)
print("Job took:", Optimization.seconds(), "seconds")

Optimization.parse_coords()
print("Atoms:", Optimization.atoms)
print("Final coordinates:")
pd.set_option('display.float_format', '{:.4e}'.format)
df = pd.DataFrame(Optimization.coords[-1])
df.columns = ['x', 'y', 'z']
df.index = ['N', 'C', 'S', 'C', 'N', 'H']
print(df)
Optimization.parse_energies()
print("Energy at convergence:")
print(Optimization.energies[-1], "Ha")
print(float(Optimization.energies[-1]) / 2.294e+17, "J")
Optimization.parse_free_energy()
print("Total SCF energy:  eV")
# Out:
# 1,2,3-thiodiazole HF 6-31(d,p) 5 - dissociated
# ORCA exited normally: True
# Job took: 31.812 seconds
# Atoms: ['N', 'C', 'S', 'C', 'N', 'H']
# Final coordinates:
#             x          y          z
# N -4.8054e+00 2.0641e+00 2.8681e+00
# C -5.6551e+00 2.1950e+00 6.0934e-01
# S -5.3243e+00 3.3211e+00 1.8500e+00
# C -5.3555e+00 9.3412e-01 1.0335e+00
# N -4.8809e+00 9.1678e-01 2.3120e+00
# H -5.4513e+00 1.6081e-02 4.9281e-01
# Energy at convergence:
# -582.590125829311 Ha
# -2.539625657494817e-15 J
# Total SCF energy:  eV
#
# 1,2,3-thiodiazole CCSD(T) 6-31(d,p) 5 - dissociated
# ORCA exited normally: True
# Job took: 11380.514 seconds
# Atoms: ['N', 'C', 'S', 'C', 'N', 'H']
# Final coordinates:
#             x          y           z
# N -4.7913e+00 2.0607e+00  2.9033e+00
# C -5.6659e+00 2.1690e+00  5.7501e-01
# S -5.3358e+00 3.3023e+00  1.8141e+00
# C -5.3395e+00 9.4502e-01  1.0806e+00
# N -4.8643e+00 8.9142e-01  2.3489e+00
# H -6.0524e+00 2.4277e+00 -3.9685e-01
# Energy at convergence:
# -583.323670343268 Ha
# -2.5428233232051785e-15 J
# Total SCF energy:  eV
#
# 1,2,3-thiodiazole MP2 6-31(d,p) 5 - dissociated
# ORCA exited normally: True
# Job took: 204.392 seconds
# Atoms: ['N', 'C', 'S', 'C', 'N', 'H']
# Final coordinates:
#             x          y          z
# N -4.7751e+00 1.9777e+00 2.9236e+00
# C -5.6241e+00 2.1944e+00 6.9362e-01
# S -5.3709e+00 3.3723e+00 1.7391e+00
# C -5.3614e+00 9.3214e-01 1.0168e+00
# N -4.8789e+00 9.5245e-01 2.3282e+00
# H -5.4621e+00 1.8227e-02 4.6441e-01
# Energy at convergence:
# -583.240143244539 Ha
# -2.5424592120511725e-15 J
# Total SCF energy:  eV

# %%
print("1,2,3-thiodiazole HF 6-31(d,p) bidissociated")
Optimization = ORCAParse("/Users/seanpaisti/Desktop/orca_tests/orca_lib/lab4/dissociated_mol/bidissassociated/HF/thiadiazoleHF_bidissassociated.out")
print("ORCA exited normally:", Optimization.valid)
print("Job took:", Optimization.seconds(), "seconds")

Optimization.parse_coords()
print("Atoms:", Optimization.atoms)
print("Final coordinates:")
pd.set_option('display.float_format', '{:.4e}'.format)
df = pd.DataFrame(Optimization.coords[-1])
df.columns = ['x', 'y', 'z']
df.index = ['N', 'C', 'S', 'C', 'N',]
print(df)
Optimization.parse_energies()
print("Energy at convergence:")
print(Optimization.energies[-1], "Ha")
print(float(Optimization.energies[-1]) / 2.294e+17, "J")
Optimization.parse_free_energy()
print("Total SCF energy:  eV\n")

print("1,2,3-thiodiazole CCSD(T) 6-31(d,p) bidissociated")
Optimization = ORCAParse("/Users/seanpaisti/Desktop/orca_tests/orca_lib/lab4/dissociated_mol/bidissassociated/CCSDT/thiadiazoleCCSDT_bidissassociated.out")
print("ORCA exited normally:", Optimization.valid)
print("Job took:", Optimization.seconds(), "seconds")

Optimization.parse_coords()
print("Atoms:", Optimization.atoms)
print("Final coordinates:")
pd.set_option('display.float_format', '{:.4e}'.format)
df = pd.DataFrame(Optimization.coords[-1])
df.columns = ['x', 'y', 'z']
df.index = ['N', 'C', 'S', 'C', 'N']
print(df)
Optimization.parse_energies()
print("Energy at convergence:")
print(Optimization.energies[-1], "Ha")
print(float(Optimization.energies[-1]) / 2.294e+17, "J")
Optimization.parse_free_energy()
print("Total SCF energy:  eV\n")

print("1,2,3-thiodiazole MP2 6-31(d,p) bidissociated")
Optimization = ORCAParse("/Users/seanpaisti/Desktop/orca_tests/orca_lib/lab4/dissociated_mol/bidissassociated/MP2/thiadiazoleMP2_bidissassociated.out")
print("ORCA exited normally:", Optimization.valid)
print("Job took:", Optimization.seconds(), "seconds")

Optimization.parse_coords()
print("Atoms:", Optimization.atoms)
print("Final coordinates:")
pd.set_option('display.float_format', '{:.4e}'.format)
df = pd.DataFrame(Optimization.coords[-1])
df.columns = ['x', 'y', 'z']
df.index = ['N', 'C', 'S', 'C', 'N']
print(df)
Optimization.parse_energies()
print("Energy at convergence:")
print(Optimization.energies[-1], "Ha")
print(float(Optimization.energies[-1]) / 2.294e+17, "J")
Optimization.parse_free_energy()
print("Total SCF energy:  eV")

# %% [markdown]
# Необходимо уточнить относительно какой диссоциации молекулы идет речь, поскольку диссоциация моей молекулы пока малоизучена
#
# Я могу попробовать расчитать так же энергию связи для тиадиазола - как лиганда или ФГ

# %% [markdown]
# Добавить заместитель
